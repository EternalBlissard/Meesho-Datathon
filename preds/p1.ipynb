# %%
import pandas as pd
data=pd.read_csv("preds8.csv")
data=data.drop(columns=["Unnamed: 0"])
data.head()
# Out:
#    id     Category  len      attr_1 attr_2   attr_3      attr_4  \
# 0   0  Men Tshirts    5  multicolor  round  printed     default
# 1   1  Men Tshirts    5       white  round  printed  typography
# 2   2  Men Tshirts    5       white  round  printed     default
# 3   3  Men Tshirts    5     default   polo    solid       solid
# 4   4  Men Tshirts    5       black  round  printed     default
#
#           attr_5    attr_6    attr_7    attr_8    attr_9   attr_10
# 0   long sleeves  default2  default2  default2  default2  default2
# 1   long sleeves  default2  default2  default2  default2  default2
# 2   long sleeves  default2  default2  default2  default2  default2
# 3  short sleeves  default2  default2  default2  default2  default2
# 4   long sleeves  default2  default2  default2  default2  default2
