# %%
import pandas as pd

# %%
df=pd.read_csv('check_Sarees.csv')
df=df[df['preds']!=1]
len(df)
# Out:
# 40

# %%
df2=pd.read_csv('train.csv')
df2=df2[df2['Category']=='Sarees']
df2.iloc[380]
# Out:
# id                   7812
# Category           Sarees
# len                    10
# attr_1            default
# attr_2            default
# attr_3                NaN
# attr_4            default
# attr_5              party
# attr_6                NaN
# attr_7      same as saree
# attr_8            default
# attr_9            default
# attr_10                no
# Name: 7647, dtype: object

# %%
from PIL import Image

# %%
img=Image.open('train_images/007812.jpg')
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x768>
